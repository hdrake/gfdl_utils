# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import gfdl_utils.core as gu

# %%
pathDict = {'pp':"/archive/Raphael.Dussin/FMS2019.01.03_devgfdl_20230608/CM4_historical_c192_OM4p125/gfdl.ncrc5-intel22-prod-openmp/pp/",
           'ppname':'ocean_annual',
           'out':'ts',
           'local':'annual/5yr',
           'time':'*2010*',
           'add':['wfo', 'prlq'],
           }

# %%
ds = gu.open_frompp(**pathDict, dmget=True)
og = gu.open_static(**{k:v for (k,v) in pathDict.items() if k in ["pp", "ppname"]}, dmget=True)
# Out:
# Issuing dmget for variables: wfo, prlq. Migration complete.
# Issuing dmget command to migrate data to disk.
# /work5/hfd/codedev/gfdl_utils/gfdl_utils/core.py:90: FutureWarning: In a future version, xarray will not decode the variable 'average_DT' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   f"with time pattern '{time}'."
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,4))
plt.subplot(1,2,1)
ds.wfo.isel(time=0).plot(robust=True)
plt.subplot(1,2,2)
ds.prlq.isel(time=0).plot(robust=True);
plt.tight_layout()
